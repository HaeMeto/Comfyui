# %% [markdown]
# # MODELS USED IN THIS WORKFLOW
#
# ## 🟣 Load Diffusion Model
# Download **Wan2.1-VACE-14B-Q4_K_M.gguf** from  [HERE](https://huggingface.co/QuantStack/Wan2.1-VACE-14B-GGUF/resolve/main/Wan2.1-VACE-14B-Q4_K_M.gguf?download=true)
#
# OR a **bigger or smaller version** from [HERE](https://huggingface.co/QuantStack/Wan2.1-VACE-14B-GGUF/tree/main)
#
# **Place in:** `ComfyUI/models/diffusion_models`
#
# ---
#
# ## 🟣 Load CLIP
# Download **umt5_xxl_fp8_e4m3fn_scaled.safetensors** from [HERE](https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true)
#
# OR a **Bigger Version FP16** from [HERE](https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/text_encoders/umt5_xxl_fp16.safetensors?download=true)
#
# **Place in:** `ComfyUI/models/text_encoders`
#
# ---
#
# ## 🟣 Load VAE
# Download **wan_2.1_vae.safetensors** from  [HERE](https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/vae/wan_2.1_vae.safetensors?download=true)
#
# **Place in:** `ComfyUI/models/vae`
#
# ---
#
# ## 🧩 Nodes Installed from Manager
#
# - **ComfyUI-GGUF**
# - **comfyui_controlnet_aux**
#
# ---
#
# ## Resources
# 🎥 **Watch tutorials** on the [Pixaroma YouTube Channel](https://www.youtube.com/@pixaroma)
# 💬 **Join discussions** on [Discord](https://discord.com/invite/gggpkVgBf3)
#
# More about Vace model on [Comfy.org](https://docs.comfy.org/tutorials/video/wan/vace) and [GitHub](https://github.com/ali-vilab/VACE)

# %%
pip install tqdm

# %%
import os
import requests

from tqdm import tqdm

# Prompt
url = input("Masukkan URL file: ").strip()
sub_dir = input("Masukkan subfolder di dalam /workspace (kosongkan untuk root /workspace): ").strip()
sub_dir = sub_dir.lstrip("/")

# Path setup
base_dir = "/workspace"
save_dir = os.path.join(base_dir, sub_dir) if sub_dir else base_dir
os.makedirs(save_dir, exist_ok=True)

filename = url.split("/")[-1].split("?")[0]
file_path = os.path.join(save_dir, filename)

# Download
response = requests.get(url, stream=True)
total_size = int(response.headers.get('content-length', 0))

if response.status_code == 200:
    with open(file_path, 'wb') as f, tqdm(
        desc=filename,
        total=total_size,
        unit='B',
        unit_scale=True,
        unit_divisor=1024
    ) as bar:
        for chunk in response.iter_content(chunk_size=8192):
            if chunk:
                f.write(chunk)
                bar.update(len(chunk))
    print(f"\n✅ File berhasil diunduh ke: {file_path}")
else:
    print(f"❌ Gagal mengunduh file. Status code: {response.status_code}")

# %% [markdown]
# Load Diffusion Model

# %%
import os
import requests

from tqdm import tqdm

# Prompt
url = "https://huggingface.co/QuantStack/Wan2.1-VACE-14B-GGUF/resolve/main/Wan2.1-VACE-14B-Q4_K_M.gguf?download=true"
sub_dir = "/ComfyUI/models/diffusion_models"
sub_dir = sub_dir.lstrip("/")

# Path setup
base_dir = "/workspace"
save_dir = os.path.join(base_dir, sub_dir) if sub_dir else base_dir
os.makedirs(save_dir, exist_ok=True)

filename = url.split("/")[-1].split("?")[0]
file_path = os.path.join(save_dir, filename)

# Download
response = requests.get(url, stream=True)
total_size = int(response.headers.get('content-length', 0))

if response.status_code == 200:
    with open(file_path, 'wb') as f, tqdm(
        desc=filename,
        total=total_size,
        unit='B',
        unit_scale=True,
        unit_divisor=1024
    ) as bar:
        for chunk in response.iter_content(chunk_size=8192):
            if chunk:
                f.write(chunk)
                bar.update(len(chunk))
    print(f"\n✅ File berhasil diunduh ke: {file_path}")
else:
    print(f"❌ Gagal mengunduh file. Status code: {response.status_code}")

# %% [markdown]
# Load CLIP

# %%
import os
import requests

from tqdm import tqdm

# Prompt
url = "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true"
sub_dir = "/ComfyUI/models/text_encoders"
sub_dir = sub_dir.lstrip("/")

# Path setup
base_dir = "/workspace"
save_dir = os.path.join(base_dir, sub_dir) if sub_dir else base_dir
os.makedirs(save_dir, exist_ok=True)

filename = url.split("/")[-1].split("?")[0]
file_path = os.path.join(save_dir, filename)

# Download
response = requests.get(url, stream=True)
total_size = int(response.headers.get('content-length', 0))

if response.status_code == 200:
    with open(file_path, 'wb') as f, tqdm(
        desc=filename,
        total=total_size,
        unit='B',
        unit_scale=True,
        unit_divisor=1024
    ) as bar:
        for chunk in response.iter_content(chunk_size=8192):
            if chunk:
                f.write(chunk)
                bar.update(len(chunk))
    print(f"\n✅ File berhasil diunduh ke: {file_path}")
else:
    print(f"❌ Gagal mengunduh file. Status code: {response.status_code}")

# %% [markdown]
# Load VAE

# %%
import os
import requests

from tqdm import tqdm

# Prompt
url = "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/vae/wan_2.1_vae.safetensors?download=true"
sub_dir = "/ComfyUI/models/vae"
sub_dir = sub_dir.lstrip("/")

# Path setup
base_dir = "/workspace"
save_dir = os.path.join(base_dir, sub_dir) if sub_dir else base_dir
os.makedirs(save_dir, exist_ok=True)

filename = url.split("/")[-1].split("?")[0]
file_path = os.path.join(save_dir, filename)

# Download
response = requests.get(url, stream=True)
total_size = int(response.headers.get('content-length', 0))

if response.status_code == 200:
    with open(file_path, 'wb') as f, tqdm(
        desc=filename,
        total=total_size,
        unit='B',
        unit_scale=True,
        unit_divisor=1024
    ) as bar:
        for chunk in response.iter_content(chunk_size=8192):
            if chunk:
                f.write(chunk)
                bar.update(len(chunk))
    print(f"\n✅ File berhasil diunduh ke: {file_path}")
else:
    print(f"❌ Gagal mengunduh file. Status code: {response.status_code}")
